# %%
import librosa.effects
import numpy as np
import pandas as pd
import soundfile as sf

import os

from ipywidgets import Audio
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm

import librosa

# %%
INFERENCE_ROOT = "/home/kwatchar3/Documents/data/moisesdb/inference/bandit-vdbo/5583712/lightning_logs/version_0"
GROUND_TRUTH_ROOT = "/home/kwatchar3/Documents/data/moisesdb"

# %%
test_files = os.listdir(os.path.join(INFERENCE_ROOT, "audio"))
gt_files = os.listdir(os.path.join(GROUND_TRUTH_ROOT, "npy2"))

# %%
def snr(gt, est):
    return 10 * np.log10(np.sum(np.square(gt)) / np.sum(np.square(gt - est)))

# %%
df = []

for song in tqdm(test_files):
    song_name = song.split(".")[0]

    stems = os.listdir(os.path.join(INFERENCE_ROOT, "audio", song))
    stems = [s.replace(".wav", "") for s in stems]

    print(f"Processing {song_name}...")

    for stem in stems:
        print(f"Processing {stem}...")

        audio_est, sr = sf.read(os.path.join(INFERENCE_ROOT, "audio", song, f"{stem}.wav"))
        audio_est = audio_est.T


        npy_path = os.path.join(GROUND_TRUTH_ROOT, "npy2", song_name, f"{stem}.npy")
        if os.path.exists(npy_path):
            audio = np.load(npy_path, mmap_mode="r")
        else:
            print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
            print(f"Ground truth not found for {song_name}/{stem}. Using zeros.")
            print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
            audio = np.zeros_like(audio_est)

        snr_full = snr(audio, audio_est)

        df.append({
            "song": song_name,
            "stem": stem,
            "snr": snr_full,
        })

        print(f"{stem} - SNR: {snr_full:-2.3f}")
        # print("Ground truth duration:", audio.shape[1] / sr)
        # print("Estimation duration:", audio_est.shape[1] / sr)



df = pd.DataFrame(df)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]
# Processing 704f1de9-1d02-4c2b-af05-107a7700a51d...
# Processing bass...
# bass - SNR: 9.485
# Processing drums...
# drums - SNR: 12.619
# Processing vdbo_others...
# vdbo_others - SNR: 1.341
# Processing vocals...
# vocals - SNR: 10.221
# Processing 8a6c9c1f-4865-404f-a805-1949de36a33c...
# Processing bass...
# bass - SNR: 17.693
# Processing drums...
# drums - SNR: 11.757
# Processing vdbo_others...
# vdbo_others - SNR: 11.729
# Processing vocals...
# vocals - SNR: 13.991
# Processing 0358fd1e-244a-4422-9a42-29b5d68f6e4b...
# Processing bass...
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Ground truth not found for 0358fd1e-244a-4422-9a42-29b5d68f6e4b/bass. Using zeros.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# /tmp/ipykernel_944710/3900712503.py:2: RuntimeWarning: divide by zero encountered in log10
#   if 10 * np.log10(np.sum(np.square(gt))) < -80 and 10 * np.log10(np.sum(np.square(est))) < -80:
# /tmp/ipykernel_944710/3900712503.py:5: RuntimeWarning: divide by zero encountered in log10
#   return 10 * np.log10(np.sum(np.square(gt)) / np.sum(np.square(gt - est)))
# bass - SNR: -inf
# Processing drums...
# drums - SNR: 3.137
# Processing vdbo_others...
# vdbo_others - SNR: 4.323
# Processing vocals...
# vocals - SNR: 7.371
# Processing 1afe1b3b-3e2e-48d3-b859-f50e222cbaf4...
# Processing bass...
# bass - SNR: 15.237
# Processing drums...
# drums - SNR: 6.423
# Processing vdbo_others...
# vdbo_others - SNR: 7.214
# Processing vocals...
# vocals - SNR: 7.470
# Processing 78ef22ce-472f-4f82-8656-16df73b9465f...
# Processing bass...
# bass - SNR: 14.379
# Processing drums...
# drums - SNR: 8.823
# Processing vdbo_others...
# vdbo_others - SNR: 7.623
# Processing vocals...
# vocals - SNR: 10.831
# Processing 491c1ff5-1e7b-4046-8029-a82d4a8aefb4...
# Processing bass...
# bass - SNR: 11.747
# Processing drums...
# drums - SNR: 8.677
# Processing vdbo_others...
# vdbo_others - SNR: 10.092
# Processing vocals...
# vocals - SNR: 14.714
# Processing f0c565c5-fc73-4da1-b979-0fac0167f671...
# Processing bass...
# bass - SNR: 15.670
# Processing drums...
# drums - SNR: 12.890
# Processing vdbo_others...
# vdbo_others - SNR: 9.983
# Processing vocals...
# vocals - SNR: 15.542
# Processing 6de41c50-0c49-4528-b60b-75c45d3630f4...
# Processing bass...
# bass - SNR: 8.983
# Processing drums...
# drums - SNR: 6.970
# Processing vdbo_others...
# vdbo_others - SNR: 5.922
# Processing vocals...
# vocals - SNR: 9.110
# Processing 25789239-1075-43b9-bfc9-51dff4a29590...
# Processing bass...
# bass - SNR: 6.716
# Processing drums...
# drums - SNR: 8.366
# Processing vdbo_others...
# vdbo_others - SNR: 5.317
# Processing vocals...
# vocals - SNR: 6.835
# Processing dc61c44e-a771-47a9-8934-a0eb8f3e08ac...
# Processing bass...
# bass - SNR: 4.713
# Processing drums...
# drums - SNR: 10.057
# Processing vdbo_others...
# vdbo_others - SNR: 6.444
# Processing vocals...
# vocals - SNR: 4.912
# Processing 07fb2df2-91d6-458d-9230-9638b4edac08...
# Processing bass...
# bass - SNR: 6.982
# Processing drums...
# drums - SNR: 13.011
# Processing vdbo_others...
# vdbo_others - SNR: 10.241
# Processing vocals...
# vocals - SNR: 7.707
# Processing 3c557409-3a34-43c2-9159-5421bbad5ecb...
# Processing bass...
# bass - SNR: 8.745
# Processing drums...
# drums - SNR: 8.830
# Processing vdbo_others...
# vdbo_others - SNR: 6.744
# Processing vocals...
# vocals - SNR: 7.409
# Processing 28748b6e-6125-42f7-998d-2ad734e39b6c...
# Processing bass...
# bass - SNR: 8.632
# Processing drums...
# drums - SNR: 9.321
# Processing vdbo_others...
# vdbo_others - SNR: -2.375
# Processing vocals...
# vocals - SNR: 9.497
# Processing 1a32e987-cae8-458f-9c26-d9a6abf5348d...
# Processing bass...
# bass - SNR: 8.614
# Processing drums...
# drums - SNR: 12.391
# Processing vdbo_others...
# vdbo_others - SNR: 7.316
# Processing vocals...
# vocals - SNR: 11.427
# Processing 0d528a19-cb0f-4421-b250-444f9343e51c...
# Processing bass...
# bass - SNR: 13.244
# Processing drums...
# drums - SNR: 9.947
# Processing vdbo_others...
# vdbo_others - SNR: 4.410
# Processing vocals...
# vocals - SNR: 9.251
# Processing 215391aa-1168-42dd-9cab-f8b0c6ff566b...
# Processing bass...
# bass - SNR: 5.713
# Processing drums...
# drums - SNR: 7.634
# Processing vdbo_others...
# vdbo_others - SNR: 6.557
# Processing vocals...
# vocals - SNR: 7.484
# Processing 606e3380-b062-4b74-88ac-b60d6f4d0a37...
# Processing bass...
# bass - SNR: 12.253
# Processing drums...
# drums - SNR: 4.114
# Processing vdbo_others...
# vdbo_others - SNR: 5.113
# Processing vocals...
# vocals - SNR: 12.230
# Processing 5640831d-7853-4d06-8166-988e2844b652...
# Processing bass...
# bass - SNR: 9.930
# Processing drums...
# drums - SNR: 8.070
# Processing vdbo_others...
# vdbo_others - SNR: 4.463
# Processing vocals...
# vocals - SNR: 8.894
# Processing a199697c-3cdc-47c7-a9c7-c1b07dd6c9dd...
# Processing bass...
# bass - SNR: 7.346
# Processing drums...
# drums - SNR: 8.666
# Processing vdbo_others...
# vdbo_others - SNR: 5.392
# Processing vocals...
# vocals - SNR: 8.850
# Processing 11845abc-8ca3-4fb2-bd84-521aeeff56f4...
# Processing bass...
# bass - SNR: -0.276
# Processing drums...
# drums - SNR: 12.249
# Processing vdbo_others...
# vdbo_others - SNR: 0.093
# Processing vocals...
# vocals - SNR: 12.225
# Processing 48c78ca6-18e9-42f2-9f05-fdbee90a7786...
# Processing bass...
# bass - SNR: 8.489
# Processing drums...
# drums - SNR: 11.663
# Processing vdbo_others...
# vdbo_others - SNR: 3.472
# Processing vocals...
# vocals - SNR: 11.567
# Processing 88b545e5-4d06-4d55-a306-1bd3a2915ee5...
# Processing bass...
# bass - SNR: 10.696
# Processing drums...
# drums - SNR: 10.053
# Processing vdbo_others...
# vdbo_others - SNR: 7.925
# Processing vocals...
# vocals - SNR: 14.239
# Processing c6d73235-1dd5-4085-a3b3-50a3466c6168...
# Processing bass...
# bass - SNR: 8.475
# Processing drums...
# drums - SNR: 10.513
# Processing vdbo_others...
# vdbo_others - SNR: 4.912
# Processing vocals...
# vocals - SNR: 4.241
# Processing 93dda0e8-dd76-49e4-b08f-54a82387cdf6...
# Processing bass...
# bass - SNR: 11.548
# Processing drums...
# drums - SNR: 5.003
# Processing vdbo_others...
# vdbo_others - SNR: 6.192
# Processing vocals...
# vocals - SNR: 8.427
# Processing 4999a0bf-a753-4e0e-85b1-690259dabf96...
# Processing bass...
# bass - SNR: 11.947
# Processing drums...
# drums - SNR: 7.625
# Processing vdbo_others...
# vdbo_others - SNR: 5.800
# Processing vocals...
# vocals - SNR: 9.006
# Processing 35983cdd-3903-46cb-b184-f96274ced57b...
# Processing bass...
# bass - SNR: 12.185
# Processing drums...
# drums - SNR: 12.861
# Processing vdbo_others...
# vdbo_others - SNR: 3.401
# Processing vocals...
# vocals - SNR: 7.116
# Processing 3e656eec-84d4-4a45-b410-d3817d849f92...
# Processing bass...
# bass - SNR: 6.314
# Processing drums...
# drums - SNR: 8.707
# Processing vdbo_others...
# vdbo_others - SNR: 6.997
# Processing vocals...
# vocals - SNR: 8.248
# Processing 7dd515b0-e218-425d-b8bf-a75056237d6a...
# Processing bass...
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Ground truth not found for 7dd515b0-e218-425d-b8bf-a75056237d6a/bass. Using zeros.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# bass - SNR: -inf
# Processing drums...
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Ground truth not found for 7dd515b0-e218-425d-b8bf-a75056237d6a/drums. Using zeros.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# drums - SNR: -inf
# Processing vdbo_others...
# vdbo_others - SNR: 13.920
# Processing vocals...
# vocals - SNR: 16.405
# Processing 5a6df5c7-a58a-479e-bdfb-c5946c221933...
# Processing bass...
# bass - SNR: 11.215
# Processing drums...
# drums - SNR: 12.070
# Processing vdbo_others...
# vdbo_others - SNR: 5.337
# Processing vocals...
# vocals - SNR: 10.006
# Processing bb45cf1a-4c58-4fe3-88ea-97ef27527507...
# Processing bass...
# bass - SNR: 9.900
# Processing drums...
# drums - SNR: 12.091
# Processing vdbo_others...
# vdbo_others - SNR: 6.341
# Processing vocals...
# vocals - SNR: 9.171
# Processing 125fc63d-9b69-4170-a46a-42c91bc28446...
# Processing bass...
# bass - SNR: 12.191
# Processing drums...
# drums - SNR: 8.565
# Processing vdbo_others...
# vdbo_others - SNR: 8.861
# Processing vocals...
# vocals - SNR: 11.347
# Processing 06bfc6e7-e5ac-4827-bf8e-ffaf1675872f...
# Processing bass...
# bass - SNR: 14.333
# Processing drums...
# drums - SNR: 9.265
# Processing vdbo_others...
# vdbo_others - SNR: 9.864
# Processing vocals...
# vocals - SNR: 13.362
# Processing a1dcaeb2-f4e6-4818-b490-09f44d624afc...
# Processing bass...
# bass - SNR: 11.080
# Processing drums...
# drums - SNR: 9.341
# Processing vdbo_others...
# vdbo_others - SNR: 5.421
# Processing vocals...
# vocals - SNR: 10.434
# Processing dda2c057-6d73-43fa-a130-d7d6562c09ca...
# Processing bass...
# bass - SNR: 12.618
# Processing drums...
# drums - SNR: 12.947
# Processing vdbo_others...
# vdbo_others - SNR: 9.321
# Processing vocals...
# vocals - SNR: 7.466
# Processing aa600069-0a98-45e6-94fa-4000bfe46c25...
# Processing bass...
# bass - SNR: 10.589
# Processing drums...
# drums - SNR: 12.593
# Processing vdbo_others...
# vdbo_others - SNR: 6.706
# Processing vocals...
# vocals - SNR: 10.007
# Processing 3c3b5fdb-f15e-4ba4-884a-b083ce2426c6...
# Processing bass...
# bass - SNR: 12.639
# Processing drums...
# drums - SNR: 10.564
# Processing vdbo_others...
# vdbo_others - SNR: 4.933
# Processing vocals...
# vocals - SNR: 8.202
# Processing 8f36f17f-c033-4c1b-a793-80dce43d507b...
# Processing bass...
# bass - SNR: 10.605
# Processing drums...
# drums - SNR: 7.292
# Processing vdbo_others...
# vdbo_others - SNR: 7.612
# Processing vocals...
# vocals - SNR: 10.577
# Processing 7bfa233c-24ed-4c7a-9096-11e3aa00c55d...
# Processing bass...
# bass - SNR: 12.023
# Processing drums...
# drums - SNR: 11.780
# Processing vdbo_others...
# vdbo_others - SNR: 7.788
# Processing vocals...
# vocals - SNR: 10.275
# Processing ad9bbefc-8762-46c9-b847-da14b10802b6...
# Processing bass...
# bass - SNR: 8.524
# Processing drums...
# drums - SNR: 10.625
# Processing vdbo_others...
# vdbo_others - SNR: 6.989
# Processing vocals...
# vocals - SNR: 7.101
# Processing 8042b88a-6179-406b-9ec4-b45a4cdd4a71...
# Processing bass...
# bass - SNR: 12.069
# Processing drums...
# drums - SNR: 7.987
# Processing vdbo_others...
# vdbo_others - SNR: 3.975
# Processing vocals...
# vocals - SNR: 7.414
# Processing 05e7af85-9721-4b42-952a-ccd34feb6033...
# Processing bass...
# bass - SNR: 9.050
# Processing drums...
# drums - SNR: 9.196
# Processing vdbo_others...
# vdbo_others - SNR: 7.297
# Processing vocals...
# vocals - SNR: 7.955
# Processing 4380ad97-2620-4419-a011-ddfa29a87f54...
# Processing bass...
# bass - SNR: 10.921
# Processing drums...
# drums - SNR: 14.987
# Processing vdbo_others...
# vdbo_others - SNR: 6.208
# Processing vocals...
# vocals - SNR: 7.960
# Processing fc3c9e48-e2ac-4088-af65-68404baa7f12...
# Processing bass...
# bass - SNR: 11.790
# Processing drums...
# drums - SNR: 10.886
# Processing vdbo_others...
# vdbo_others - SNR: 5.631
# Processing vocals...
# vocals - SNR: 9.253
# Processing c70471f9-9c4a-41c9-b8f8-20ac38847a8e...
# Processing bass...
# bass - SNR: 10.281
# Processing drums...
# drums - SNR: 11.319
# Processing vdbo_others...
# vdbo_others - SNR: 10.939
# Processing vocals...
# vocals - SNR: 9.360
# Processing adb5e3fd-d039-42e4-b09b-fd0784fa0c82...
# Processing bass...
# bass - SNR: 7.585
# Processing drums...
# drums - SNR: 8.285
# Processing vdbo_others...
# vdbo_others - SNR: 2.680
# Processing vocals...
# vocals - SNR: 8.242
# Processing 6b48c9de-fa34-4635-9718-04e01a03a0fe...
# Processing bass...
# bass - SNR: 10.041
# Processing drums...
# drums - SNR: 6.297
# Processing vdbo_others...
# vdbo_others - SNR: 7.171
# Processing vocals...
# vocals - SNR: 7.895
# Processing a56d9450-3a26-485c-8ac3-24b6b54e2c1d...
# Processing bass...
# bass - SNR: 16.180
# Processing drums...
# drums - SNR: 12.425
# Processing vdbo_others...
# vdbo_others - SNR: 10.969
# Processing vocals...
# vocals - SNR: 14.003
# Processing 1f98fe4d-26c7-460f-9f68-33964bc4d8d3...
# Processing bass...
# bass - SNR: 8.926
# Processing drums...
# drums - SNR: 10.736
# Processing vdbo_others...
# vdbo_others - SNR: 4.453
# Processing vocals...
# vocals - SNR: 4.565

# %%
df["snr"] = df["snr"].replace(-np.inf, np.nan)

# %%
df.to_csv(os.path.join(INFERENCE_ROOT, "bandit4.csv"), index=False)
